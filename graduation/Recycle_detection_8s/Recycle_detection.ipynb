# %%
import os
from ultralytics import YOLO

# --- 설정 ---

# 1. 모델 선택
model = YOLO('yolov8s.pt')

dataset_folder = r'/home/asd/projects/Portfolio/graduation/taco_dataset'


# 2) 위 폴더 경로와 'data.yaml' 파일 이름을 합쳐서 최종 경로를 완성합니다.
data_yaml_path = os.path.join(dataset_folder, 'data.yaml')

# %%
# 3. 훈련 파라미터 설정
epochs_count = 100
image_size = 640
batch_size = 6

# %%
# --- 훈련 시작 ---

results = model.train(
    data=data_yaml_path,
    epochs=epochs_count,
    imgsz=image_size,
    batch=batch_size
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.215 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214 🚀 Python-3.10.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...
